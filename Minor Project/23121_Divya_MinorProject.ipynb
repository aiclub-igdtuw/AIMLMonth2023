# %% [markdown]
# # **MINOR PROJECT**
#
# Iris Flower Dataset
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
url = 'https://drive.google.com/uc?id={}'.format("1lVSRoiLCSwSrW215_Zn2NpNuYvO0Fxog")
df = pd.read_csv(url)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # **TASK 1** - Exploratory Data Analysis

# %% [markdown]
# **Q1) a) Are there any missing values in the dataset? If so, how will you handle them?**

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# **No**, there are no missing values in the dataset.

# %% [markdown]
#  **Q1) b) What is the distribution of the species variable? Are there an equal number of samples for each species?**

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
#  Each of the species ( Iris-setosa, Iris-versicolor, Iris-virginica) has ***50 samples*** i.e. ***equal*** number of samples are present for all 3 species.

# %% [markdown]
# **Q2) How do the sepal length, sepal width, petal length, and petal width vary across the three species of Iris?**
#
# **Visualize them using box plots and violin plots.**

# %%
sns.boxplot(data=df, x='species', y="sepal_length")
plt.title('Variation of Sepal Length across the species')
plt.ylabel("Sepal Length")
plt.show()

sns.boxplot(data=df, x="species", y="sepal_width")
plt.title('Variation of Sepal Width across the species')
plt.ylabel("Sepal Width")
plt.show()

sns.boxplot(data=df, x="species", y="petal_length")
plt.title('Variation of Petal Length across the species')
plt.ylabel("Petal Length")
plt.show()

sns.boxplot(data=df, x="species", y="petal_width")
plt.title('Variation of Petal width across the species')
plt.ylabel("Petal Width")
plt.show()

# %%
sns.violinplot(data=df, x='species', y="sepal_length")
plt.title('Variation of Sepal Length across the species')
plt.ylabel("Sepal Length")
plt.show()

sns.violinplot(data=df, x="species", y="sepal_width")
plt.title('Variation of Sepal Width across the species')
plt.ylabel("Sepal Width")
plt.show()

sns.violinplot(data=df, x="species", y="petal_length")
plt.title('Variation of Petal Length across the species')
plt.ylabel("Petal Length")
plt.show()

sns.violinplot(data=df, x="species", y="petal_width")
plt.title('Variation of Petal width across the species')
plt.ylabel("Petal Width")
plt.show()

# %% [markdown]
# 1) **Iris Setosa:**
# petals are small in length and width
# sepal is small in length but large in width
#
# 2) **Iris Versicolor:**
# avg petal length and width
# avg sepal length and width
#
# 3) **Iris Virginica:**
# petals are big in length and width
# sepal is large in length but small in width
#
# Distribution of the 3 species varies significantly.

# %% [markdown]
# **Q3) Are there any correlations between the different features? Visualize the correlations using a heatmap or correlation matrix? Can you determine if any feature(s) can be dropped based on their relationship with the target variable.**

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(data=df.corr(), annot=True, cmap="GnBu")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# We won't drop any feature since all of them plays a lot but if we have to choose one feature then it would be **sepal_width**  because it has correlations close to 0 . This would affect value of target variable the least since it is **less correlated** as compared to other 3 features. We can observe this since all the other 3 factors have positive values whereas only sepal width has **negative values**.

# %% [markdown]
# **Q4) a) How does the petal length vary with respect to the petal width for different species of Iris? Can you visualize it using scatter plots or categorical scatter plots?**

# %%
sns.scatterplot(data=df, x='petal_width', y='petal_length', hue='species', style='species')
plt.title('Petal Length vs Petal Width (Scatter Plot)')
plt.xlabel('Petal Width')
plt.ylabel('Petal Length')
plt.show()

# %% [markdown]
# 1) **Iris Setosa:**
# small petal length and width
#
# 2) **Iris Virginica:**
# large petal length and width
#
# 3) **Iris Versicolor:**
# range of petal length > range of petal width

# %% [markdown]
# **Q4) b)Visualize the distribution of each feature using histograms or density plots. Are there any interesting observations or patterns? Summarize your observations.**

# %%
sns.histplot(data=df, x='petal_length', hue='species',kde = True)
plt.title('Petal Length')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data=df, x='petal_width', hue='species',kde = True)
plt.title('Petal Width')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data=df, x='sepal_length', hue='species',kde = True)
plt.title('Sepal Length')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data=df, x='sepal_width', hue='species',kde = True)
plt.title('Sepal Width')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 1) **petal length** - setosa is easily distinguishable
#                 - 4 to 5.5 versicolor and virginica overlap
#
#
# 2) **petal width**  - setosa is easily distinguishable
#                 - 1.25 to 2.0 versicolor and virginica overlap
#
#
# 3) **sepal length** - less distinct patterns
#                 - all 3 overlapping after 4.5 to 6
#
#
# 4) **sepal width**  - symmetric distribution
#                 - hard to distinguish
#                 - since least distinct patterns

# %% [markdown]
# **Q5) Can you analyze the pairwise correlations between the features? Are there any features that are highly correlated with each other? How might you handle multicollinearity if present?**

# %%
corr= df.corr()
print(corr)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
high_corr= df.drop("species", axis=1).corr()
high_corr= corr.abs() > 0.8
corr_features = set()
for i in range(len(high_corr.columns)):
    for j in range(i):
        if high_corr.iloc[i, j]:
            colname = high_corr.columns[i]
            corr_features.add(colname)

print("Highly correlated features:", corr_features)
# Out:
# Highly correlated features: {'petal_length', 'petal_width'}

# %%
sns.heatmap(data=df.corr(), annot=True, cmap="coolwarm")
plt.title('Pairwise Correlation between the features')
plt.show()

# %% [markdown]
# 1) **Sepal length** has a strong positive correlation with **petal length (0.87)** and **petal width (0.82)**
#
# 2) **Sepal width** has a weak negative correlation with **sepal length (-0.11)** and **petal width (-0.36)** and **petal length (-0.42)**
#
# 3) **Petal length** and **petal width** have the strongest positive correlation **(0.96)** This high correlation can lead to multicollinearity. To handle this we can either remove one of the highly correlated features or use techniques like Ridge regression that reduces correlated features and stabilises the coefficients.

# %% [markdown]
# # **TASK 2** - Classification/Regression

# %% [markdown]
# Perform following steps on the same dataset which you used for EDA.
# > - Data Preprocessing (as per requirement)
# > - Feature Engineering
# > - Split dataset in train-test (80:20 ratio)
# > - Model selection
# > - Model training
# > - Model evaluation
# > - Fine-tune the Model
# > - Make predictions
#
# Summarize your model's performance by evaluation metrices

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df.drop('species', axis=1)
Y = df['species']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_train,Y_train)
# Out:
# 0.9666666666666667

# %%
model.score(X_test, Y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score, precision_score
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred, average='weighted')
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Accuracy: 1.0
# Precision: 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(X_train,Y_train)
# Out:
# 0.9833333333333333

# %%
model.score(X_test, Y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import accuracy_score, precision_score
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred, average='weighted')
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Accuracy: 0.9666666666666667
# Precision: 0.9694444444444444

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,Y_train)
# Out:
# 1.0

# %%
model.score(X_test, Y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score, precision_score
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred, average='weighted')
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Accuracy: 1.0
# Precision: 1.0

# %% [markdown]
# Among Logistic Regression, KNeighbours Classifier and Decision Tree Classifier, the highest accuracy we got is **96.67%**  and precision 96.92% is from **KNeighbours Classifier**.
