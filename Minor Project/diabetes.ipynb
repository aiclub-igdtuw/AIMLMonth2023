# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a='diabetes.csv'

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0              6      148             72             35        0  33.6  \
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   768.000000  768.000000     768.000000     768.000000  768.000000  \
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
print(df.groupby('Outcome').size())
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %% [markdown]
# # out of 768 people 268 are diagnosed with diabetes and others are not

# %%
df.plot.scatter(x='Glucose',y='Outcome',c='DarkBlue')
# Out:
# <Axes: xlabel='Glucose', ylabel='Outcome'>

# %%
df.plot.scatter(x='SkinThickness',y='BloodPressure',c='Outcome')
# Out:
# <Axes: xlabel='SkinThickness', ylabel='BloodPressure'>

# %%
x1=df['BMI']
x2=df['Outcome']

# %%
plt.hist([x1,x2],label=['BMI','OUTCOME'],bins=10,alpha=0.5)

plt.show()

# %%
diabetes = df[df['Outcome'] == 1]
no_diabetes = df[df['Outcome'] == 0]

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0              6      148             72             35        0  33.6  \
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
no_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              1       85             66             29        0  26.6  \
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
mean_age_diabetes = diabetes['Age'].mean()
mean_age_no_diabetes = no_diabetes['Age'].mean()

# %%
mean_age_diabetes
# Out:
# 37.06716417910448

# %%
mean_age_no_diabetes
# Out:
# 31.19

# %%
np.sum(diabetes['Age'])/268
# Out:
# 37.06716417910448

# %%
np.sum(no_diabetes['Age'])/500
# Out:
# 31.19
