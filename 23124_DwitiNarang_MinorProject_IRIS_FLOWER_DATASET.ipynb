# %% [markdown]
# # MINOR **PROJECT**

# %% [markdown]
# #  Task 1 - Exploratory Data Analysis
#
# ---

# %%
# !wget https://www.dropbox.com/s/qgse7ikc2k9lupa/IRIS.csv?dl
# Out:
# --2023-06-29 09:11:24--  https://www.dropbox.com/s/qgse7ikc2k9lupa/IRIS.csv?dl
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/qgse7ikc2k9lupa/IRIS.csv [following]
# --2023-06-29 09:11:24--  https://www.dropbox.com/s/raw/qgse7ikc2k9lupa/IRIS.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf5b266b5d97a804efc00ac4885.dl.dropboxusercontent.com/cd/0/inline/B-4YN6UKE7tgyQp5T-n0PfE4MFwmUPJEInsStzJfYdHy4cqDVr9qOY6X5Px2emTGqoMFARE8PYojQ1tcMbPJDKV1RFMFbzArn8ectipDqF030dAY1ArqRBnkZZlqFT68ApsZJYrtpLBntLVfdrzPPfAYsdBWPsqvfbfzRX2x_iytpw/file# [following]
# ...

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd
from sklearn.decomposition import PCA
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('IRIS.csv?dl')

# %%
data.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %% [markdown]
# ### Q1. Are there any missing values in the dataset? If so, how will you handle them? What is the distribution of the species variable? Are there an equal number of samples for each species?

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# No, there is no missing value in this dataset

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(data.groupby('species').size())
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# Yes, there are equal number of samples for each species

# %% [markdown]
# ## Q.2  How do the sepal length, sepal width, petal length, and petal width vary across the three species of Iris? Visualize them using box plots and violin plots.

# %%
vars = data.columns.values.tolist()
vars
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %% [markdown]
# ### **Box plot for each parameter**

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(y=vars[0], data=data)
plt.show()

# %%
sns.set_style("darkgrid")

sns.boxplot(y=vars[0], data=data)
plt.show()

# %%
sns.boxplot(x='species', y=data[vars[0]], data=data)
plt.ylabel(vars[0])
plt.show()

# %%
sns.boxplot(x='species', y=data[vars[0]], data=data)
plt.ylabel(vars[0])
sns.stripplot(x='species', y=data[vars[0]], data=data, jitter=True, size=3, color='black')
plt.show()

# %%
sns.boxplot(y=vars[1], data=data)
plt.show()

# %%
sns.set_style("darkgrid")

sns.boxplot(y=vars[1], data=data)
plt.show()

# %%
sns.boxplot(x='species', y=data[vars[1]], data=data)
plt.ylabel(vars[1])
plt.show()

# %%
sns.boxplot(x='species', y=data[vars[1]], data=data)
plt.ylabel(vars[0])
sns.stripplot(x='species', y=data[vars[1]], data=data, jitter=True, size=3, color='black')
plt.show()

# %%
sns.boxplot(y=vars[2], data=data)
plt.show()

# %%
sns.boxplot(x='species', y=data[vars[2]], data=data)
plt.ylabel(vars[2])
plt.show()

# %%
sns.boxplot(x='species', y=data[vars[2]], data=data)
plt.ylabel(vars[2])
sns.stripplot(x='species', y=data[vars[2]], data=data, jitter=True, size=3, color='black')
plt.show()

# %%
sns.boxplot(y=vars[3], data=data)
plt.show()

# %%
sns.boxplot(x='species', y=data[vars[3]], data=data)
plt.ylabel(vars[3])
plt.show()

# %%
sns.boxplot(x='species', y=data[vars[3]], data=data)
plt.ylabel(vars[3])
sns.stripplot(x='species', y=data[vars[3]], data=data, jitter=True, size=3, color='black')
plt.show()

# %% [markdown]
# ## Violin plots for all the **parameters**

# %%
sns.violinplot(y=data[vars[0]])

plt.ylabel(vars[0])
plt.show()

# %%
sns.violinplot(x='species', y=data[vars[0]], data=data)
plt.ylabel(vars[0])
plt.show()

# %%
fig, axs = plt.subplots(1, len(vars)-1, figsize=(15,5))
for i in range(0,len(vars)-1):
    sns.violinplot(x='species', y=data[vars[i]], data=data,ax=axs[i])
    axs[i].set_ylabel(vars[i])

plt.show()

# %% [markdown]
# ## Q.3 Are there any correlations between the different features? Visualize the correlations using a heatmap or correlation matrix? Can you determine if any feature(s) can be dropped based on their relationship with the target variable.

# %%
data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
corr=data.corr()
fig, ax =plt.subplots(figsize=(10,10))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ## **Yes, there are correlations between the different features in the Iris flower dataset.**

# %%
data = pd.read_csv('IRIS.csv?dl')

# %%
species=['sepal_length','sepal_width','petal_length','petal_width']

# %%
features = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
target = data['species']

# %%
data = sns.load_dataset('iris')
correlation_matrix = data.corr()
correlation_with_target = correlation_matrix['sepal_length']


print(correlation_with_target)
# Out:
# sepal_length    1.000000
# sepal_width    -0.117570
# petal_length    0.871754
# petal_width     0.817941
# Name: sepal_length, dtype: float64

# %% [markdown]
# ## Q4. How does the petal length vary with respect to the petal width for different species of Iris? Can you visualize it using scatter plots or categorical scatter plots? Visualize the distribution of each feature using histograms or density plots. Are there any interesting observations or patterns? Summarize your observations.

# %%
petal_data = data[['petal_length', 'petal_width', 'species']]

sns.scatterplot(data=petal_data, x='petal_width', y='petal_length', hue='species')

plt.title('Petal Length vs Petal Width for different Iris species')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Petal Length (cm)')


plt.show()

# %%
features = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

for feature in features.columns:
    sns.histplot(data=data, x=feature, kde=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# Sepal Length: The distribution appears to be roughly bell-shaped
#
# Sepal Width: The distribution shows two distinct peaks, indicating the presence of two subgroups.
#
# Petal Length: The distribution exhibits clear separation between three groups, indicating the presence of distinct clusters for each Iris species.
#
# **Petal** Width: Similar to petal length, the distribution also displays distinct separation between three groups, aligning with the different Iris species.

# %% [markdown]
# ### Q5. Can you analyze the pairwise correlations between the features? Are there any features that are highly correlated with each other? How might you handle multicollinearity if present?

# %%
features = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
correlation_matrix = features.corr()

# %%
print(correlation_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
highly_correlated = []
threshold = 0.8

# %%
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        if abs(correlation_matrix.iloc[i, j]) >= threshold:
            feature_i = correlation_matrix.columns[i]
            feature_j = correlation_matrix.columns[j]
            correlation = correlation_matrix.iloc[i, j]
            highly_correlated.append((feature_i, feature_j, correlation))

# %%
if len(highly_correlated) > 0:
    print("Highly correlated features:")
    for correlation in highly_correlated:
        feature_i, feature_j, correlation_value = correlation
        print(f"{feature_i} and {feature_j}: {correlation_value}")
else:
    print("No highly correlated features found.")
# Out:
# Highly correlated features:
# sepal_length and petal_length: 0.8717537758865838
# sepal_length and petal_width: 0.8179411262715758
# petal_length and petal_width: 0.962865431402796

# %% [markdown]
# 1.Remove some of the highly correlated independent variables.
#
# 2.Linearly combine the independent variables, such as adding them together.
#
# 3.Partial least squares regression uses principal component analysis to create a set of uncorrelated components to include in the model.

# %% [markdown]
# # Task 2 - Classification And Regression:
#
# ---

# %% [markdown]
# ## Data **Preprocessing**

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Model Selection, Model Training And Model Evaluation

# %%
from sklearn.model_selection import train_test_split
#train - 80
#test - 20
X=data.drop(columns=['species'])
Y=data['species']
x_train , x_test, y_train, y_test = train_test_split(X,Y,test_size=0.20)

# %% [markdown]
# ## Prediction using differnt Algorithims

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
print("Accuracy:", model.score(x_test,y_test))
# Out:
# Accuracy: 0.9333333333333333

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test))
# Out:
# Accuracy: 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test))
# Out:
# Accuracy: 0.9666666666666667
