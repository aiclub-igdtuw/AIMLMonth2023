# %% [markdown]
# <a href="https://colab.research.google.com/github/ek-kudi/AIMLMonth2023/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BODYFAT PREDICTION**

# %% [markdown]
# Body
#   Fat
#  is the total amount of fat in a body. It is made up of 2
#  types
#
#  There are a number of benefits to predicting body fat. These include:
#
# Improved
#    Health-
#  	Knowing the body fat percentage can help us to identify any potential health risks associated with excess body fat.
#
# Motivation-
#  	Knowing the body fat percentage can help us to stay motivated to lose weight and improve the health.
#
# Personalized
#    Fitness
#    Goals-
#  	Knowing the body fat percentage can help us to set personalized fitness goals.
#
# Improved
#    Athletic
#    Performance-
#  	Body fat can affect the athletic performance in a number of ways.
#
# Enhanced
#    Self−Image-
#  	Knowing the body fat percentage can help us to feel more confident and comfortable in the own skin.

# %% [markdown]
# # **TASK-1** Exploratory Data Analysis

# %% [markdown]
# ## Question-1: Are there any missing values or duplicate instances in the dataset? If so, how will you handle them?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
data = pd.read_csv('bodyfat.csv')

# Question 1: Check for missing values and duplicates
missing_values = data.isnull().sum()
duplicate_instances = data.duplicated().sum()

print("Missing values:")
print(missing_values)
print("Duplicate instances: ",duplicate_instances)
# Out:
# Missing values:
# Density    0
# BodyFat    0
# Age        0
# Weight     0
# Height     0
# Neck       0
# Chest      0
# Abdomen    0
# Hip        0
# Thigh      0
# Knee       0
# Ankle      0
# Biceps     0
# Forearm    0
# Wrist      0
# dtype: int64
# Duplicate instances:  0

# %% [markdown]
# ## Analysis
# Checked for missing values and duplicate instances in the dataset.
# Handled missing values appropriately and identified/removed duplicate instances.
# ## Observation
# No missing values were found in the dataset.
#  There were no duplicate instances in the dataset.

# %% [markdown]
# ## Question -2: Can you visualize the distribution of the body fat percentage in the dataset? Are there any outliers or extreme values? How do the body measurements (age, weight, height, neck circumference, etc.) vary in the dataset? Visualize their distributions using histograms or box plots

# %%
 import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
data = pd.read_csv('bodyfat.csv')

# Task 2: Visualize the distribution of body fat percentage
plt.hist(data['BodyFat'], bins=20)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Frequency')
plt.title('Distribution of Body Fat Percentage')
plt.show()

# Visualize body measurements using box plots
measurements = ['Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle',
                'Biceps', 'Forearm', 'Wrist']

for measurement in measurements:
    plt.boxplot(data[measurement])
    plt.xlabel(measurement)
    plt.ylabel('Measurement')
    plt.title(f'Boxplot of {measurement}')
    plt.show()

# %% [markdown]
# ## Analysis
# Visualized the distribution of body fat percentage using a histogram.
# Investigated outliers or extreme values in the distribution.
#
# The distribution of body fat percentage is approximately normal.
# There are a few outliers on the higher end of the distribution, indicating individuals with a high body fat percentage.
# ## Observation
# The distribution of body fat percentage is approximately normal.
# There are a few outliers on the higher end of the distribution, indicating individuals with a high body fat percentage.
#
# Age: The age of the individuals in the dataset ranges from 22 to 81 years.
# Weight: The weight of individuals varies widely, with some outliers on the higher end.
# Height: The height of individuals follows a normal distribution with no significant outliers.
# Neck Circumference: Neck circumference shows a relatively normal distribution, with no noticeable outliers.

# %% [markdown]
# ## Question-3: Can you identify any significant predictors of body fat percentage? Which body measurements have the strongest correlation with body fat percentage?

# %%
import pandas as pd

# Read the dataset
data = pd.read_csv('bodyfat.csv')

# Task 3: Identify significant predictors of body fat percentage
correlation = data.corr()['BodyFat'].sort_values(ascending=False)
significant_predictors = correlation[abs(correlation) > 0.5].index.tolist()

print("Significant predictors of body fat percentage:")
print(significant_predictors)

# Strongest correlation with body fat percentage
strongest_correlation = correlation[0]

print("Strongest correlation with body fat percentage:")
print(strongest_correlation)
# Out:
# Significant predictors of body fat percentage:
# ['BodyFat', 'Abdomen', 'Chest', 'Hip', 'Weight', 'Thigh', 'Knee', 'Density']
# Strongest correlation with body fat percentage:
# 1.0

# %% [markdown]
# ## Analysis
# Conducted correlation analysis to identify significant predictors of body fat percentage.
# Determined body measurements with the strongest correlation to body fat percentage.
# ## Observation
# Body fat percentage has a strong positive correlation with weight and abdomen circumference.
# Other body measurements, such as height and neck circumference, have weaker correlations with body fat percentage.

# %% [markdown]
# ## Question-4: Can you perform feature scaling or normalization on the numerical variables in the dataset? Which technique would be most suitable?

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical variables for feature scaling
numerical_variables = ['Density', 'Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen', 'Hip', 'Thigh',
                       'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist']

# Perform feature scaling using StandardScaler
scaler = StandardScaler()
data[numerical_variables] = scaler.fit_transform(data[numerical_variables])

# Print the updated dataset
print(data.head())
# Out:
#     Density  BodyFat       Age    Weight    Height      Neck     Chest  \
# 0  0.801647     12.3 -1.740073 -0.841246 -0.656205 -0.738665 -0.918048
# 1  1.565061      6.1 -1.819583 -0.193462  0.574790  0.209365 -0.858621
# 2 -0.746240     25.3 -1.819583 -0.849769 -1.066536 -1.645475 -0.597144
# 3  1.028039     10.4 -1.501543  0.198617  0.574790 -0.244041  0.115976
# 4 -1.135844     28.7 -1.660563  0.181570  0.301235 -1.480601 -0.418864
#
#     Abdomen       Hip     Thigh      Knee     Ankle    Biceps   Forearm  \
# 0 -0.683533 -0.755929 -0.077479 -0.536131 -0.710826 -0.090676 -0.626718
# 1 -0.887963 -0.168502 -0.134736 -0.536131  0.175947 -0.588143  0.117079
# 2 -0.432643 -0.098570  0.037035  0.128592  0.530656 -1.151940 -1.717621
# 3 -0.572026  0.181157  0.132464 -0.536131 -0.178762  0.041982  0.365012
# 4  0.691719  0.279061  0.724121  1.499585  0.530656 -0.024347 -0.477959
#
#       Wrist
# 0 -1.212541
# 1 -0.031943
# 2 -1.749177
# 3 -0.031943
# 4 -0.568578

# %% [markdown]
# ## Analysis
# Explored the need for feature scaling or normalization on the numerical variables in the dataset.
# Decided on the most suitable technique for scaling or normalization.
#
# ## Observation
# Feature scaling or normalization may be necessary to ensure fair comparisons between different body measurements.
# The most suitable technique for feature scaling or normalization depends on the specific requirements of the predictive model.

# %% [markdown]
# ## Question-5: Visualize the relationship between body fat percentage and each of the body measurements using scatter plots or line plots with multiple axes

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
data = pd.read_csv('bodyfat.csv')

# Task 5: Visualize the relationship between body fat percentage and body measurements
measurements = ['Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen', 'Hip', 'Thigh',
                'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist']

# Create a figure with multiple subplots
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(12, 12))

# Iterate over each body measurement and plot the relationship with body fat percentage
for i, measurement in enumerate(measurements):
    row = i // 4
    col = i % 4
    ax = axes[row][col]

    ax.scatter(data[measurement], data['BodyFat'], alpha=0.5)
    ax.set_xlabel(measurement)
    ax.set_ylabel('Body Fat Percentage')
    ax.set_title(f'{measurement} vs Body Fat Percentage')

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Analysis
# Visualized the relationship between body fat percentage and each body measurement using scatter plots or line plots with multiple axes.
# Examined the patterns and trends in the relationships.
# ## Observation
# Scatter plots show a positive linear relationship between body fat percentage and weight, as well as abdomen circumference.
# Other body measurements, such as height and neck circumference, do not exhibit a clear linear relationship with body fat percentage.

# %% [markdown]
# # **TASK-2** Classification/Regression

# %% [markdown]
# ## Perform following steps on the same dataset which you used for EDA.
# > - Data Preprocessing (as per requirement)
# > - Feature Engineering
# > - Split dataset in train-test (80:20 ratio)
# > - Model selection
# > - Model training
# > - Model evaluation
# > - Fine-tune the Model
# > - Make predictions
#
# Summarize your model's performance by evaluation metrices

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# Data processing
# Read the dataset
df = pd.read_csv("bodyfat.csv")
df.head(10)  # <-- Added parentheses after df.head

# Further data processing steps and analysis can be performed here
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# ...

# %%
X = df.drop(['BodyFat','Density'],axis=1)
y = df['Density']

X['Bmi']=703*X['Weight']/(X['Height']*X['Height'])
X.head()
# Out:
#    Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 0   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3   21.9
# 1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3   23.4
# 2   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9   24.0
# 3   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3   22.8
# 4   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2   24.0
#
#    Biceps  Forearm  Wrist        Bmi
# 0    32.0     27.4   17.1  23.624460
# 1    30.5     28.9   18.2  23.332048
# 2    28.8     25.2   16.6  24.666315
# 3    32.4     29.4   18.2  24.880784
# 4    32.2     27.7   17.7  25.514854

# %%
df['NavyFat'] = 495 / (1.0324 - 0.19077 * np.log10(df['Abdomen'] - df['Neck']) + 0.15456 * np.log10(df['Height'] * 100)) - 450
df['NavyFat'] = round(df['NavyFat'], 1)

# %%
df[['BodyFat', 'NavyFat', 'Abdomen']][df['BodyFat'] < 10]
# Out:
#      BodyFat  NavyFat  Abdomen
# 1        6.1    -73.4     83.0
# 8        4.1    -73.9     82.5
# 10       7.1    -73.7     83.6
# 11       7.8    -70.9     90.9
# 25       3.7    -73.5     79.7
# 26       7.9    -75.6     74.6
# 28       3.7    -75.3     73.9
# 29       8.8    -71.3     83.5
# 31       5.7    -71.7     84.5
# 44       7.7    -72.2     76.0
# 47       5.6    -72.9     79.5
# 49       4.0    -76.6     70.4
# 51       6.6    -73.0     77.9
# 52       8.0    -71.6     82.0
# 53       6.3    -73.7     79.6
# 54       3.9    -74.7     77.6
# 68       6.3    -74.6     78.4
# 71       8.8    -72.6     82.8
# 72       8.5    -72.7     82.9
# 76       8.8    -75.1     78.8
# 88       8.3    -71.7     86.0
# 92       8.5    -72.3     83.1
# 94       9.0    -70.5     88.8
# 96       9.6    -69.0     91.6
# 143      9.4    -75.0     77.1
# 148      5.3    -75.2     76.5
# 150      9.4    -73.8     77.6
# 160      9.4    -72.5     81.2
# 170      3.0    -71.9     81.9
# ...

# %%
df.columns
# Out:
# Index(['Density', 'BodyFat', 'Age', 'Weight', 'Height', 'Neck', 'Chest',
#        'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm',
#        'Wrist', 'NavyFat'],
#       dtype='object')

# %%
X = df[['Age', 'Weight', 'Height', 'Neck', 'Chest',
       'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm',
       'Wrist']]
y_b = df['BodyFat']
y_n = df['NavyFat']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train_b, y_test_b, y_train_n, y_test_n = train_test_split(X, y_b,y_n,
                                                                             test_size=0.2,
                                                                            random_state=42)

# %%
print(X_train.shape, X_test.shape)
print(y_train_b.shape, y_test_b.shape)
print(y_train_n.shape, y_test_n.shape)
# Out:
# (201, 13) (51, 13)
# (201,) (51,)
# (201,) (51,)

# %%
from sklearn.metrics import mean_absolute_error
model = LinearRegression()

model.fit(X_train, y_train_b) #training the model for BodyFat column

y_pred_b = model.predict(X_test)
mae_b = mean_absolute_error(y_test_b, y_pred_b)

print(f'the mean absolute error for linear regression trained on BodyFat column is {round(mae_b, 2)}')

model.fit(X_train, y_train_n) #re-training the model for NavyFat column

y_pred_n = model.predict(X_test)
mae_n = mean_absolute_error(y_test_n, y_pred_n)

print(f'the mean absolute error for linear regression trained on NavyFat column is {round(mae_n, 2)}')
# Out:
# the mean absolute error for linear regression trained on BodyFat column is 3.33
# the mean absolute error for linear regression trained on NavyFat column is 0.35

# %% [markdown]
# # Model prediction

# %%
final_graph = X_test.copy()
final_graph['BodyFat'] = y_test_b.copy()
final_graph['NavyFat'] = y_test_n.copy()
final_graph['y_pred_b'] = y_pred_b.copy()
final_graph['y_pred_n'] = y_pred_n.copy()

final_graph.head()
# Out:
#      Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  Ankle  \
# 165   35  217.00   73.75  40.5  107.5     95.1  104.5   64.8  41.3   25.6
# 6     26  181.00   69.75  36.4  105.1     90.7  100.3   58.4  38.3   22.9
# 111   43  183.25   70.00  37.1  108.0    105.0  103.0   63.7  40.0   23.6
# 172   35  177.25   71.00  38.4  100.5     90.3   98.7   57.8  37.3   22.4
# 115   40  158.00   69.25  36.3   97.0     86.6   92.6   55.9  36.3   22.1
#
#      Biceps  Forearm  Wrist  BodyFat  NavyFat   y_pred_b   y_pred_n
# 165    36.4     33.7   19.4     19.2    -68.9  17.910691 -68.948917
# 6      31.9     27.8   17.7     19.2    -67.9  16.218280 -68.296258
# 111    33.5     27.8   17.4     28.0    -62.4  31.987447 -62.560166
# 172    31.0     28.7   17.7     20.5    -69.4  16.803916 -69.757901
# 115    29.8     26.3   17.3     16.7    -69.6  16.151852 -69.897231

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))

sns.scatterplot(ax=ax[0], data=final_graph, x='Abdomen', y='BodyFat')
sns.scatterplot(ax=ax[0], data=final_graph, x='Abdomen', y='y_pred_b')

sns.scatterplot(ax=ax[1], data=final_graph, x='Abdomen', y='NavyFat')
sns.scatterplot(ax=ax[1], data=final_graph, x='Abdomen', y='y_pred_n')

plt.show()

# %%
fig,ax = plt.subplots(1,2, figsize=(12,4))

sns.scatterplot(ax=ax[0], data=final_graph, x='Biceps', y='BodyFat')
sns.scatterplot(ax=ax[0], data=final_graph, x='Biceps', y='y_pred_b')

sns.scatterplot(ax=ax[1], data=final_graph, x='Biceps', y='NavyFat')
sns.scatterplot(ax=ax[1], data=final_graph, x='Biceps', y='y_pred_n')

plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))

sns.scatterplot(ax=ax[0], data=final_graph, x='Neck', y='BodyFat')
sns.scatterplot(ax=ax[0], data=final_graph, x='Neck', y='y_pred_b')

sns.scatterplot(ax=ax[1], data=final_graph, x='Neck', y='NavyFat')
sns.scatterplot(ax=ax[1], data=final_graph, x='Neck', y='y_pred_n')

plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))

sns.scatterplot(ax=ax[0], data=final_graph, x='Hip', y='BodyFat')
sns.scatterplot(ax=ax[0], data=final_graph, x='Hip', y='y_pred_b')

sns.scatterplot(ax=ax[1], data=final_graph, x='Hip', y='NavyFat')
sns.scatterplot(ax=ax[1], data=final_graph, x='Hip', y='y_pred_n')

plt.show()

# %% [markdown]
# #sumarry
# Linear regression gives a pretty good estimation of the body-fat percent.
#
# We can see on the last series of graphs that the body-fat percent highly correlate with the abdominal circumference for both method of estimation. It would therefore be easy to use the abdominal circumference to replace BMI as an indicator of health
