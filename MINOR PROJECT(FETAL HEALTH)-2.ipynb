# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # task-1 EDA

# %% [markdown]
# ## 1.Normal<br>
# ## 2.Suspect<br>
# ## 3.Pathological <br>

# %%
url="Downloads/fetal_health.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
df.columns
# Out:
# Index(['baseline value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %%
df.dtypes
# Out:
# baseline value                                            float64
# accelerations                                             float64
# fetal_movement                                            float64
# uterine_contractions                                      float64
# light_decelerations                                       float64
# severe_decelerations                                      float64
# prolongued_decelerations                                  float64
# abnormal_short_term_variability                           float64
# mean_value_of_short_term_variability                      float64
# percentage_of_time_with_abnormal_long_term_variability    float64
# mean_value_of_long_term_variability                       float64
# histogram_width                                           float64
# histogram_min                                             float64
# histogram_max                                             float64
# ...

# %%
df['fetal_health'].value_counts()
# Out:
# 1.0    1655
# 2.0     295
# 3.0     176
# Name: fetal_health, dtype: int64

# %% [markdown]
# ## missing values in the dataset and how to handle them

# %%
df.isnull().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %% [markdown]
# ## there are no missing values to be handeled

# %% [markdown]
# ## Are there any duplicate entries in the dataset that need to be identified and removed?

# %%
x=df.duplicated(subset=None)

# %%
df[x]
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 68             140.0          0.007           0.000                 0.004
# 234            123.0          0.000           0.000                 0.000
# 306            145.0          0.000           0.020                 0.000
# 324            135.0          0.000           0.000                 0.000
# 333            144.0          0.000           0.019                 0.000
# 787            123.0          0.003           0.003                 0.000
# 791            123.0          0.003           0.004                 0.000
# 798            146.0          0.000           0.000                 0.003
# 849            138.0          0.002           0.000                 0.004
# 1113           122.0          0.000           0.000                 0.000
# 1114           122.0          0.000           0.000                 0.000
# 1115           122.0          0.000           0.000                 0.000
# ...

# %% [markdown]
# ## the duplicated values need not be removed as FHR,acceraltions and rest of the values can <br> be repeated for a different feteus

# %%
df.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %% [markdown]
# ## are there any inconsistent data or need for standardization

# %%
df["fetal_health"]
# Out:
# 0       2.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 2121    2.0
# 2122    2.0
# 2123    2.0
# 2124    2.0
# 2125    1.0
# Name: fetal_health, Length: 2126, dtype: float64

# %%
df.describe().T
# Out:
#                                                      count        mean  \
# baseline value                                      2126.0  133.303857
# accelerations                                       2126.0    0.003178
# fetal_movement                                      2126.0    0.009481
# uterine_contractions                                2126.0    0.004366
# light_decelerations                                 2126.0    0.001889
# severe_decelerations                                2126.0    0.000003
# prolongued_decelerations                            2126.0    0.000159
# abnormal_short_term_variability                     2126.0   46.990122
# mean_value_of_short_term_variability                2126.0    1.332785
# percentage_of_time_with_abnormal_long_term_vari...  2126.0    9.846660
# mean_value_of_long_term_variability                 2126.0    8.187629
# histogram_width                                     2126.0   70.445908
# ...

# %%
df['fetal_health'].value_counts(normalize=True)*100
# Out:
# 1.0    77.845720
# 2.0    13.875823
# 3.0     8.278457
# Name: fetal_health, dtype: float64

# %%
z=df['fetal_health']==2
df_sus=df[z]
df_sus.head()
# Out:
#     baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0            120.0          0.000           0.000                 0.000
# 10           151.0          0.000           0.000                 0.001
# 11           150.0          0.000           0.000                 0.001
# 17           131.0          0.002           0.383                 0.003
# 28           132.0          0.000           0.135                 0.001
#
#     light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                 0.000                   0.0                     0.000
# 10                0.001                   0.0                     0.000
# 11                0.001                   0.0                     0.000
# 17                0.005                   0.0                     0.002
# 28                0.008                   0.0                     0.001
#
#     abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
y=df["fetal_health"]==1
df_nor=df[y]
df_nor.head()
# Out:
#     baseline value  accelerations  fetal_movement  uterine_contractions  \
# 1            132.0          0.006           0.000                 0.006
# 2            133.0          0.003           0.000                 0.008
# 3            134.0          0.003           0.000                 0.008
# 4            132.0          0.007           0.000                 0.008
# 12           131.0          0.005           0.072                 0.008
#
#     light_decelerations  severe_decelerations  prolongued_decelerations  \
# 1                 0.003                   0.0                       0.0
# 2                 0.003                   0.0                       0.0
# 3                 0.003                   0.0                       0.0
# 4                 0.000                   0.0                       0.0
# 12                0.003                   0.0                       0.0
#
#     abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
x=df['fetal_health']==3
df_path=df[x]
df_path.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 5           134.0          0.001             0.0                 0.010
# 6           134.0          0.001             0.0                 0.013
# 7           122.0          0.000             0.0                 0.000
# 8           122.0          0.000             0.0                 0.002
# 9           122.0          0.000             0.0                 0.003
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 5                0.009                   0.0                     0.002
# 6                0.008                   0.0                     0.003
# 7                0.000                   0.0                     0.000
# 8                0.000                   0.0                     0.000
# 9                0.000                   0.0                     0.000
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
df_nor.describe().T
# Out:
#                                                      count          mean  \
# baseline value                                      1655.0  1.319819e+02
# accelerations                                       1655.0  3.992145e-03
# fetal_movement                                      1655.0  7.963142e-03
# uterine_contractions                                1655.0  4.780665e-03
# light_decelerations                                 1655.0  1.941390e-03
# severe_decelerations                                1655.0  6.042296e-07
# prolongued_decelerations                            1655.0  5.135952e-05
# abnormal_short_term_variability                     1655.0  4.246586e+01
# mean_value_of_short_term_variability                1655.0  1.430634e+00
# percentage_of_time_with_abnormal_long_term_vari...  1655.0  5.044713e+00
# mean_value_of_long_term_variability                 1655.0  8.705498e+00
# histogram_width                                     1655.0  7.340000e+01
# ...

# %%
df_path.describe().T
# Out:
#                                                     count        mean  \
# baseline value                                      176.0  131.687500
# accelerations                                       176.0    0.000392
# fetal_movement                                      176.0    0.025676
# uterine_contractions                                176.0    0.003784
# light_decelerations                                 176.0    0.003670
# severe_decelerations                                176.0    0.000034
# prolongued_decelerations                            176.0    0.001273
# abnormal_short_term_variability                     176.0   64.539773
# mean_value_of_short_term_variability                176.0    1.575568
# percentage_of_time_with_abnormal_long_term_vari...  176.0   22.846591
# mean_value_of_long_term_variability                 176.0    3.588636
# histogram_width                                     176.0   78.346591
# ...

# %%
df_sus.describe().T
# Out:
#                                                     count        mean  \
# baseline value                                      295.0  141.684746
# accelerations                                       295.0    0.000275
# fetal_movement                                      295.0    0.008332
# uterine_contractions                                295.0    0.002390
# light_decelerations                                 295.0    0.000536
# severe_decelerations                                295.0    0.000000
# prolongued_decelerations                            295.0    0.000095
# abnormal_short_term_variability                     295.0   61.901695
# mean_value_of_short_term_variability                295.0    0.638983
# percentage_of_time_with_abnormal_long_term_vari...  295.0   29.030508
# mean_value_of_long_term_variability                 295.0    8.026102
# histogram_width                                     295.0   49.159322
# ...

# %% [markdown]
# ## there is no inconsistent data and the fetal health data has not been changed to object from <br> float as its esaier to work with numerical data

# %% [markdown]
# ## Q3 can we visualize the the features of the fetal health status

# %% [markdown]
# ## yes we can visualize the relation of fetal status by using heat maps

# %%
corrmat= df.corr()
plt.figure(figsize=(15,15))  

cmap = sns.diverging_palette(250, 10, s=80, l=55, n=9, as_cmap=True)

sns.heatmap(corrmat,annot=True, cmap=cmap, center=0)
plt.show()

# %% [markdown]
# df.corr()

# %%
df['fetal_health'].corr(method='pearson',other=df['prolongued_decelerations'])
# Out:
# 0.4848591863213482

# %%
df['fetal_health'].corr(method='pearson',other=df['abnormal_short_term_variability'])
# Out:
# 0.47119075284667566

# %%
df['fetal_health'].corr(method='pearson',other=df['percentage_of_time_with_abnormal_long_term_variability'])
# Out:
# 0.42614641992406366

# %% [markdown]
# ## feteal haelth has a moderately strong correlation with prolongued decelerations,abnormal short term variability,'percentage of time with abnormal long term variability as can been <br>
# ## seen by correlation and pearson coefficent

# %% [markdown]
# # task 2:  classification

# %% [markdown]
# ## extracting features

# %%
x= df.drop(['fetal_health'],axis=1)
y=df['fetal_health'].values

# %% [markdown]
# ## sacling of features

# %%
from sklearn.preprocessing import StandardScaler
col_names=list(x.columns)
sc_x=StandardScaler()
x_df=sc_x.fit_transform(x.values)
x_df=pd.DataFrame(x_df,columns=col_names)
x_df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0       -1.352220      -0.822388        -0.20321             -1.482465
# 1       -0.132526       0.730133        -0.20321              0.554627
# 2       -0.030884      -0.046128        -0.20321              1.233657
# 3        0.070757      -0.046128        -0.20321              1.233657
# 4       -0.132526       0.988886        -0.20321              1.233657
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0            -0.638438             -0.057476                 -0.268754
# 1             0.375243             -0.057476                 -0.268754
# 2             0.375243             -0.057476                 -0.268754
# 3             0.375243             -0.057476                 -0.268754
# 4            -0.638438             -0.057476                 -0.268754
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_df,y,test_size=0.2,random_state=0)
x_train=x_tarin.values
x_test=x_test.values

# %% [markdown]
# ## model selection

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## model training

# %%
classifier=LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred=classifier.predict(x_test)

# %% [markdown]
# ## model evaluation

# %%
from sklearn.metrics import accuracy_score
  
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.8896713615023474

# %%
from sklearn.metrics import confusion_matrix
  
cm = confusion_matrix(y_test, y_pred)
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[309  14   3]
#  [ 19  37   2]
#  [  3   6  33]]

# %% [markdown]
# ## the model can 88.9 % make right predictions
